# %% [markdown]
# # matplotlib gallery
# See also https://www.python-graph-gallery.com/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(context="paper" , style ="whitegrid",rc={"figure.facecolor":"white"})
import statsmodels.api as sm

# %load_ext autoreload
# %autoreload 2

# can install via `pip install contextplt` 
import contextplt

# custom module.
import gallery

# %%
# https://www.statsmodels.org/devel/datasets/generated/anes96.html
anes96 = sm.datasets.anes96
df = anes96.load_pandas().data

# %% [markdown]
# # Continuous to continuous

# %%
gallery.simple_scatter()

# %%
gallery.scatter_with_linear_reg()

# %%
gallery.contourplot()

# %%
gallery.histogram2d()

# %% [markdown]
# # Continuous to continuous with stratification

# %%
gallery.run_stratified_scatter()

# %% [markdown]
# # Continuous with stratification

# %%
gallery.kde_density_with_stratification()

# %%
gallery.kde_density_area_plot()

# %%
gallery.kde_density_and_area_plot_with_stratification()
