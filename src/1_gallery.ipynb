# %% [markdown]
# # matplotlib gallery
# See also https://www.python-graph-gallery.com/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(context="paper" , style ="whitegrid",rc={"figure.facecolor":"white"})
import statsmodels.api as sm

# %load_ext autoreload
# %autoreload 2

# can install via `pip install contextplt` 
import contextplt as cplt

# custom module.
import gallery

# %%
# https://www.statsmodels.org/devel/datasets/generated/anes96.html
anes96 = sm.datasets.anes96
df = anes96.load_pandas().data
x = "age"
y = "logpopul"
c = "educ"

# %% [markdown]
# # Usage of texts.

# %%
gallery.illustration_of_text_objects()

# %%
gallery.illustration_of_legend_objects()

# %%
gallery.create_legend_by_oneself()

# %% [markdown]
# # Continuous to continuous

# %%
gallery.run_simple_scatter()

# %%
gallery.run_scatter_with_linear_reg()

# %%
gallery.run_contourplot()

# %%
gallery.run_histogram2d()

# %% [markdown]
# # Continuous to continuous with stratification

# %%
gallery.run_stratified_scatter()

# %% [markdown]
# # Continuous with stratification

# %%
gallery.run_stacked_histogram()

# %%
gallery.run_kde_density_with_stratification()

# %%
gallery.run_kde_density_area_plot()

# %%
gallery.run_stacked_hist_kde_density_and_area_plot_with_stratification()

# %% [markdown]
# # Time series visualizeation

# %%
gallery.run_time_series_simple_barplot()

# %%
gallery.run_time_series_barplot()

# %%
gallery.run_timeseries_heatmap()
